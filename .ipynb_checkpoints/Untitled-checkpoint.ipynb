# %% [markdown]
# # Hoax

# %%
import keras
from keras.preprocessing import pad_sequences
from keras.models import Sequential 
from keras.layers import Dense, Flatten, Dropout, Embedding
from keras.callbacks import ModelCheckpoint # save results from each of epochs
from sklearn.metrics import roc_auc_score
import pandas as pd 
import matplotlib.pyplot as plt 
import os 
# %matplotlib inline

# %% [markdown]
# ### set hyperparameters

# %%
output_dir = 'model_output/dense'

# training
epochs = 4 
batch_size = 128

# vector space embedding
n_dim = 64
n_unique_words = 5000 # perlu di optimalisasi 
n_words_to_skip = 50 # skip n_words most commons words
max_review_length = 100 # maybe tidak berguna
pad_type = trunc_type = 'pre' # kalau text kurang dari 100 length, tambahin, kalau lebih di kurangi

# neural network architecture
n_dense = 64
dropout = .5

# %% [markdown]
# ### load data
# - [ ] coba pakai `keras.preprocessing.text.Tokenizer`

# %%
(x_train, y_train), (x_val, y_val) = # perlu di bikin split method

# %% [markdown]
# # testing

# %%
import pandas as pd 
import os

# %%
os.listdir()
df = pd.read_csv('data.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-98a7b4c22f1a> in <module>
#       1 os.listdir()
# ----> 2 df = pd.read_csv('data.csv')
#
# ~/miniconda/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
import pandas as pd

# %%
print(f'{len(df)}/3211')
# Out:
# 1983/3211

# %%
import tqdm

# %%
import time 
from IPython.display import clear_output
for i in range(1,3211): 
    df = pd.read_csv('eya.csv')
    print(f'{len(df)}/3211')
    time.sleep(.5)
    clear_output()
# Out:
# 3210/3211
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-188bd2acaae6> in <module>()
#       4     df = pd.read_csv('eya.csv')
#       5     print(f'{len(df)}/3211')
# ----> 6     time.sleep(.5)
#       7     clear_output()
#
# KeyboardInterrupt:

# %%
df = pd.read_csv('eya.csv')
len(df)
# Out:
# 2974

# %%
from tqdm import tqdm
for i in tqdm(range(2697,3211)):
    df = pd.read_csv('eya.csv')
#     print(f'{len(df)}/3211')
#     time.sleep(.5)
    ...
# Out:
# ...
# 100%|██████████| 514/514 [00:50<00:00, 10.32it/s]

# %%
_
# Out:
# 2697
